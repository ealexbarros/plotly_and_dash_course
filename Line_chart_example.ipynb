# %% [markdown]
# <a href="https://colab.research.google.com/github/ealexbarros/plotly_and_dash_course/blob/master/Line_chart_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
np.random.seed(56)

# %%
x_values = np.linspace(0,1,100)
y_values = np.random.rand(100)
trace = go.Scatter(x=x_values,y=y_values+5, mode ='markers', name='markers')

# %%
data = [trace]
layout = go.Layout(title='Line Charts')
fig = go.Figure(data=data,layout=layout)
pyo.plot(fig,filename='scatter_line.html')
# Out:
# 'scatter_line.html'

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f2d4217-5f72-4013-8cc5-3978149eec95" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f2d4217-5f72-4013-8cc5-3978149eec95")) {
#                     Plotly.newPlot(
#                         '8f2d4217-5f72-4013-8cc5-3978149eec95',
# ...

# %%
trace1 = go.Scatter(x=x_values,y=y_values, mode ='lines', name='mylines')
data = [trace, trace1]

# %%
fig = go.Figure(data=data,layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7c8da83e-607e-421b-bc17-b80299a55cca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7c8da83e-607e-421b-bc17-b80299a55cca")) {
#                     Plotly.newPlot(
#                         '7c8da83e-607e-421b-bc17-b80299a55cca',
# ...

# %%
trace2 = go.Scatter(x=x_values,y=y_values-5, mode ='lines+markers', name='myfavorite')

# %%
data = [trace, trace1, trace2]
fig = go.Figure(data=data,layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="86cd0347-889b-4ee1-8d39-34c4a01aec14" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("86cd0347-889b-4ee1-8d39-34c4a01aec14")) {
#                     Plotly.newPlot(
#                         '86cd0347-889b-4ee1-8d39-34c4a01aec14',
# ...

# %% [markdown]
# #Using real data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://www2.census.gov/programs-surveys/popest/datasets/2010-2017/national/totals/nst-est2017-alldata.csv')
df.head()
# Out:
#    SUMLEV REGION DIVISION  ...  RNETMIG2015 RNETMIG2016  RNETMIG2017
# 0    10.0      0        0  ...     3.516743    3.513394     3.423941
# 1    20.0      1        0  ...    -0.903931   -1.307503    -0.288930
# 2    20.0      2        0  ...    -1.323952   -1.160735    -0.191323
# 3    20.0      3        0  ...     7.336162    7.113818     6.304010
# 4    20.0      4        0  ...     5.067452    5.488965     4.737979
#
# [5 rows x 121 columns]

# %%
df2 = df[df['DIVISION']=='1']
# set the index to state name:
df2.set_index('NAME', inplace=True)
# grab just the population columns:
list_of_pop_columns = [col for col in df2.columns if col.startswith('POP')]
df2 = df2[list_of_pop_columns]
df2.head()
# Out:
#                POPESTIMATE2010  ...  POPESTIMATE2017
# NAME                            ...
# Connecticut          3580171.0  ...        3588184.0
# Maine                1327568.0  ...        1335907.0
# Massachusetts        6564943.0  ...        6859819.0
# New Hampshire        1316700.0  ...        1342795.0
# Rhode Island         1053169.0  ...        1059639.0
#
# [5 rows x 8 columns]

# %%
traces=[go.Scatter(
    x = df2.columns,
    y = df2.loc[name],
    mode = 'markers+lines',
    name = name
) for name in df2.index]


layout = go.Layout(
    title = 'Population Estimates of the Six New England States'
)
fig = go.Figure(data=traces,layout=layout)
#pyo.plot(fig, filename='line3.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f2151125-4b1e-4cad-ba03-015edc35d2d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f2151125-4b1e-4cad-ba03-015edc35d2d0")) {
#                     Plotly.newPlot(
#                         'f2151125-4b1e-4cad-ba03-015edc35d2d0',
# ...
